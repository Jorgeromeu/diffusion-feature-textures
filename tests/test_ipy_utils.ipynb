# %%
# %load_ext autoreload
# %autoreload 2
import os

os.chdir("/home/jorge/thesis")

from text3d2video.utilities.video_util import pil_frames_to_clip

from text3d2video.artifacts.video_artifact import VideoArtifact

video_art = VideoArtifact.from_wandb_artifact_tag("video:latest")
video = pil_frames_to_clip(video_art.read_frames())

# %%
from text3d2video.utilities.ipython_utils import display_vid

display_vid(video, height=512)
# Out:
# <video controls   height="512">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
