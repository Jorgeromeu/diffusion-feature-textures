# %%
# %load_ext autoreload
# %autoreload 2

from text3d2video.artifacts.video_artifact import VideoArtifact


video_art = VideoArtifact.from_wandb_artifact_tag('video:latest')
video = video_art.get_moviepy_clip()

# %%
video.ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
from text3d2video.utilities.ipython_utils import display_vid


display_vid(video, resolution=512)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
from text3d2video.utilities.ipython_utils import display_vids
from IPython.display import HTML

display_vids([video, video, video])
# Out:
# <div style="display: flex; gap: 10px;"><video width="300" controls><source src="../__temp__/vid_0.mp4" type="video/mp4"></video><video width="300" controls><source src="../__temp__/vid_1.mp4" type="video/mp4"></video><video width="300" controls><source src="../__temp__/vid_2.mp4" type="video/mp4"></video></div>
