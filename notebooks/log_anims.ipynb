# %%
from scripts.log_animation_usd import create_animation_from_usd

usd_path = '/home/jorge/untitled.usdc'

art = create_animation_from_usd('breakdance', usd_path)
# Out:
# 100%|██████████| 100/100 [00:14<00:00,  6.90it/s]

# %%
from text3d2video.artifacts.anim_artifact import AnimationArtifact
from text3d2video.rendering import render_depth_map
from text3d2video.utilities.video_util import pil_frames_to_clip

frame_indices = art.frame_indices(60)
cams, meshes = art.load_frames(frame_indices)
depths = render_depth_map(meshes, cams, )

pil_frames_to_clip(depths, fps=15).ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
import wandb

wandb.init(project="diffusion-3D-features", job_type="log_artifact")
art.log_if_enabled()
wandb.finish()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: romeu. Use `wandb login --relogin` to force relogin
# wandb version 0.19.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/home/jorge/thesis/wandb/run-20250304_111543-3pjgi2x1</code>
# Syncing run <strong><a href='https://wandb.ai/romeu/diffusion-3D-features/runs/3pjgi2x1' target="_blank">bright-aardvark-1831</a></strong> to <a href='https://wandb.ai/romeu/diffusion-3D-features' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/romeu/diffusion-3D-features' target="_blank">https://wandb.ai/romeu/diffusion-3D-features</a>
# ...

# %%
anim = AnimationArtifact.from_wandb_artifact_tag('kick:latest')
frame_indices = anim.frame_indices(30)
cams, meshes = anim.load_frames(frame_indices)
depths = render_depth_map(meshes, cams)
pil_frames_to_clip(depths, fps=15).ipython_display()
# Out:
# wandb:   4 of 4 files downloaded.
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
