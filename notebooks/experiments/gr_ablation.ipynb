# %%
# %load_ext autoreload
# %autoreload 2

from scripts.experiments.gr_ablation import GrAblation
from hydra.initialize import initialize
from hydra.compose import compose

e = GrAblation(None)
with initialize(version_base=None, config_path="config"):
    e.config = compose(config_name=e.experiment_name)

# %%
len(e.specification())
# Out:
# 3

# %%
e.sync_experiment(dry_run=False)
# Out:
# Deleting 3 runs
# Executing 3 runs
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: romeu. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /home/jorge/thesis/wandb/run-20250224_232427-ql5d9e2x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run comic-waterfall-1781
# wandb: ⭐️ View project at https://wandb.ai/romeu/diffusion-3D-features
# wandb: 🚀 View run at https://wandb.ai/romeu/diffusion-3D-features/runs/ql5d9e2x
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00,  5.44it/s]
# 100%|██████████| 10/10 [00:47<00:00,  4.70s/it]
# Moviepy - Building video /tmp/local_artifacts/video/video/video.mp4.
# Moviepy - Writing video /tmp/local_artifacts/video/video/video.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/local_artifacts/video/video/video.mp4
# wandb: Adding directory to artifact (/tmp/local_artifacts/video/video)... Done. 0.0s
# wandb:
# wandb: 🚀 View run comic-waterfall-1781 at: https://wandb.ai/romeu/diffusion-3D-features/runs/ql5d9e2x
# wandb: ⭐️ View project at: https://wandb.ai/romeu/diffusion-3D-features
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 6 other file(s)
# wandb: Find logs at: ./wandb/run-20250224_232427-ql5d9e2x/logs
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: romeu. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /home/jorge/thesis/wandb/run-20250224_232531-e4jcrj3j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eager-bush-1782
# wandb: ⭐️ View project at https://wandb.ai/romeu/diffusion-3D-features
# wandb: 🚀 View run at https://wandb.ai/romeu/diffusion-3D-features/runs/e4jcrj3j
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00,  5.62it/s]
# 100%|██████████| 10/10 [00:25<00:00,  2.50s/it]
# Moviepy - Building video /tmp/local_artifacts/video/video/video.mp4.
# Moviepy - Writing video /tmp/local_artifacts/video/video/video.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/local_artifacts/video/video/video.mp4
# wandb: Adding directory to artifact (/tmp/local_artifacts/video/video)... Done. 0.0s
# wandb:
# wandb: 🚀 View run eager-bush-1782 at: https://wandb.ai/romeu/diffusion-3D-features/runs/e4jcrj3j
# wandb: ⭐️ View project at: https://wandb.ai/romeu/diffusion-3D-features
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 6 other file(s)
# wandb: Find logs at: ./wandb/run-20250224_232531-e4jcrj3j/logs
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: romeu. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /home/jorge/thesis/wandb/run-20250224_232611-qynvxfhc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run spring-monkey-1783
# wandb: ⭐️ View project at https://wandb.ai/romeu/diffusion-3D-features
# wandb: 🚀 View run at https://wandb.ai/romeu/diffusion-3D-features/runs/qynvxfhc
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00,  5.46it/s]
# 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# Moviepy - Building video /tmp/local_artifacts/video/video/video.mp4.
# Moviepy - Writing video /tmp/local_artifacts/video/video/video.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/local_artifacts/video/video/video.mp4
# wandb: Adding directory to artifact (/tmp/local_artifacts/video/video)... Done. 0.0s
# wandb:
# wandb: 🚀 View run spring-monkey-1783 at: https://wandb.ai/romeu/diffusion-3D-features/runs/qynvxfhc
# wandb: ⭐️ View project at: https://wandb.ai/romeu/diffusion-3D-features
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 6 other file(s)
# wandb: Find logs at: ./wandb/run-20250224_232611-qynvxfhc/logs

# %%
e.video_comparison().ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
