# %%
# %load_ext autoreload
# %autoreload 2


from text3d2video.experiments.gr_ablation import GenRenderingAblation

e = GenRenderingAblation(n_inference_steps=1)
e.prompt = "Stormtrooper"
e.animation_artifact_tag = "mixamo-human_rotation:latest"

# %%
e.execute_runs_in_place("rotation_stormtrooper")
# Out:
# Deleting 1 runs
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: romeu. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/home/jorge/thesis/wandb/run-20241224_190934-2hn1zfkk</code>
# Syncing run <strong><a href='https://wandb.ai/romeu/diffusion-3D-features/runs/2hn1zfkk' target="_blank">trim-leaf-1203</a></strong> to <a href='https://wandb.ai/romeu/diffusion-3D-features' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/romeu/diffusion-3D-features' target="_blank">https://wandb.ai/romeu/diffusion-3D-features</a>
#  View run at <a href='https://wandb.ai/romeu/diffusion-3D-features/runs/2hn1zfkk' target="_blank">https://wandb.ai/romeu/diffusion-3D-features/runs/2hn1zfkk</a>
# ...
# 100%|██████████| 1/1 [00:03<00:00,  3.43s/it]
# ...

# %%
GenRenderingAblation.plot_results(group="rotation_stormtrooper", labels=False).ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
