# %%
# %load_ext autoreload
# %autoreload 2

from scripts.experiments.main_experiment import MainExperiment
from hydra.initialize import initialize
from hydra.compose import compose

e = MainExperiment(None)
with initialize(version_base=None, config_path="config"):
    e.config = compose(config_name=e.experiment_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
e.specification()
# Out:
# [RunDescriptor(run_fun=<scripts.run_generative_rendering.RunGenerativeRendering object at 0x724e66680bb0>, config={'run': {'wandb': True, 'instant_exit': False, 'download_artifacts': False, 'name': None, 'group': None, 'tags': []}, 'prompt': 'Realistic Deadpool, Simple White Background', 'animation': {'n_frames': 20, 'artifact_tag': 'handstand:latest'}, 'generative_rendering': {'attend_to_self_kv': True, 'do_pre_attn_injection': False, 'do_post_attn_injection': False, 'feature_blend_alpha': 1.0, 'mean_features_weight': 0.5, 'chunk_size': 5, 'num_keyframes': 10, 'num_inference_steps': 10, 'guidance_scale': 7.5, 'controlnet_conditioning_scale': 1.0, 'module_paths': ['up_blocks.1.attentions.0.transformer_blocks.0.attn1', 'up_blocks.1.attentions.1.transformer_blocks.0.attn1', 'up_blocks.1.attentions.2.transformer_blocks.0.attn1', 'up_blocks.2.attentions.0.transformer_blocks.0.attn1', 'up_blocks.2.attentions.1.transformer_blocks.0.attn1', 'up_blocks.2.attentions.2.transformer_blocks.0.attn1', 'up_blocks.3.attentions.0.transformer_blocks.0.attn1', 'up_blocks.3.attentions.1.transformer_blocks.0.attn1', 'up_blocks.3.attentions.2.transformer_blocks.0.attn1']}, 'noise_initialization': {'_target_': 'text3d2video.noise_initialization.UVNoiseInitializer', 'noise_channels': 4, 'noise_resolution': 64, 'noise_texture_res': 64}, 'model': {'scheduler': {'_target_': 'diffusers.DPMSolverMultistepScheduler'}, 'sd_repo': 'runwayml/stable-diffusion-v1-5', 'controlnet_repo': 'lllyasviel/control_v11f1p_sd15_depth'}, 'seed': 0})]

# %%
e.execute_runs(dry_run=False)
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: romeu. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/home/jorge/thesis/wandb/run-20250223_190341-e0w2t7jq</code>
# Syncing run <strong><a href='https://wandb.ai/romeu/diffusion-3D-features/runs/e0w2t7jq' target="_blank">unique-morning-1699</a></strong> to <a href='https://wandb.ai/romeu/diffusion-3D-features' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/romeu/diffusion-3D-features' target="_blank">https://wandb.ai/romeu/diffusion-3D-features</a>
#  View run at <a href='https://wandb.ai/romeu/diffusion-3D-features/runs/e0w2t7jq' target="_blank">https://wandb.ai/romeu/diffusion-3D-features/runs/e0w2t7jq</a>
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:18<00:00,  1.87s/it]
# Moviepy - Building video /tmp/local_artifacts/video/video/video.mp4.
# Moviepy - Writing video /tmp/local_artifacts/video/video/video.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/local_artifacts/video/video/video.mp4
# wandb: Adding directory to artifact (/tmp/local_artifacts/video/video)... Done. 0.0s
# VBox(children=(Label(value='2.513 MB of 2.513 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">unique-morning-1699</strong> at: <a href='https://wandb.ai/romeu/diffusion-3D-features/runs/e0w2t7jq' target="_blank">https://wandb.ai/romeu/diffusion-3D-features/runs/e0w2t7jq</a><br/> View project at: <a href='https://wandb.ai/romeu/diffusion-3D-features' target="_blank">https://wandb.ai/romeu/diffusion-3D-features</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 6 other file(s)
# Find logs at: <code>./wandb/run-20250223_190341-e0w2t7jq/logs</code>

# %%
e.video_comparison().ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
